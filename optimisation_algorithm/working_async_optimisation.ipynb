# %%
import numpy as np
import pyproj

# %%
mid_point = [1.3662438032069444, 103.83320768517596]
num_points = 2
bearing = 0
bearings = np.arange(0, 360, 360/num_points)

geodesic = pyproj.Geod(ellps='WGS84')

grid_points = [mid_point]

longs, lats, fwd_az = geodesic.fwd(lons=[mid_point[1]]*num_points, lats=[mid_point[0]]*num_points, az=bearings, dist=[5*1000]*num_points)

longs.append(mid_point[1])
lats.append(mid_point[0])
grid_points = np.vstack((lats,longs)).transpose()


grid_points
# Out:
# array([[  1.41146201, 103.83320769],
#        [  1.32102558, 103.83320769],
#        [  1.3662438 , 103.83320769]])

# %%
array1 = np.array([[1, 2], [3, 4]])
array2 = np.array([[5, 6], [7, 8]])
result = np.tile(array1, (len(array2), 1))
result
# Out:
# array([[1, 2],
#        [3, 4],
#        [1, 2],
#        [3, 4]])

# %%
for i in range(len(array2)):
   result[i::len(array2)] = array2[i]
result
# Out:
# array([[5, 6],
#        [7, 8],
#        [5, 6],
#        [7, 8]])

# %%
a = np.array([[1, 2], [3, 4]])

# Repeat each row twice
result = np.repeat(a, 2, axis=0)

print(result)
# Out:
# [[1 2]
#  [1 2]
#  [3 4]
#  [3 4]]

# %%
locations = [
    {'coor': [1,2], 'freq': 1, 'travel_type': 1},
    {'coor': [3,4], 'freq': 2, 'travel_type': 2}
]


travel_location = np.array([[x['coor'][0], x['coor'][1]] for x in locations])
travel_frequency = np.array([[x['freq']]for x in locations])
travel_type = np.array([[x['travel_type'] ]for x in locations])

search_locations = np.array([
    [1,2],
    [3,4]
])

num_search_location = len(search_locations)
num_locations = len(locations)

# %%
travel_type
# Out:
# array([[1],
#        [2]])

# %%
travel_location = np.tile(travel_location, (num_search_location,1))
travel_frequency = np.tile(travel_frequency, (num_search_location,1))
travel_type = np.tile(travel_type, (num_search_location,1))

expand_search_array = np.repeat(search_locations, num_locations, axis=0)

# %%
travel_location
# Out:
# array([[1, 2],
#        [3, 4],
#        [1, 2],
#        [3, 4]])

# %%
travel_type
# Out:
# array([[1],
#        [2],
#        [1],
#        [2]])

# %%
expand_search_array
# Out:
# array([[1, 2],
#        [1, 2],
#        [3, 4],
#        [3, 4]])

# %%
travel_time = np.array([[1],[1],[1],[1]])

costs = np.exp(travel_time)*travel_frequency
costs
# Out:
# array([[2.71828183],
#        [5.43656366],
#        [2.71828183],
#        [5.43656366]])

# %%
expand_search_array
# Out:
# array([[1, 2],
#        [1, 2],
#        [3, 4],
#        [3, 4]])

# %%
cost_vectors = np.array([[1,2],[3,4],[5,6],[7,8]])

# %%
result = np.array([np.sum(cost_vectors[np.all(expand_search_array==val, axis=1)],axis=0) for val in search_locations])
result
# Out:
# array([[ 4,  6],
#        [12, 14]])

# %%
for val in search_locations:
    print(np.all(expand_search_array==val, axis=1))
# Out:
# [ True  True False False]
# [False False  True  True]

# %%
search_locations
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
search_locations[:,1]
# Out:
# array([2, 4])

# %%
geodesic = pyproj.Geod(ellps='WGS84')
fwd_azimuth,back_azimuth,distance = geodesic.inv(
    lats1=expand_search_array[:,0], 
    lons1=expand_search_array[:,1], 
    lats2=travel_location[:,0], 
    lons2=travel_location[:,1]
)

# %%
fwd_azimuth.reshape(4,1)
# Out:
# array([[ 180.        ],
#        [  45.14416881],
#        [-134.78601439],
#        [ 180.        ]])

# %%
unqiue = np.unique(expand_search_array, axis=0)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
expand_search_array
# Out:
# array([[1, 2],
#        [1, 2],
#        [3, 4],
#        [3, 4]])

# %%
[[expand_search_array == val] for val in search_locations]
# Out:
# [[array([[ True,  True],
#          [ True,  True],
#          [False, False],
#          [False, False]])],
#  [array([[False, False],
#          [False, False],
#          [ True,  True],
#          [ True,  True]])]]

# %%
a = np.array([[1,2],[-3,4]])

# Calculate the bearing for each element in the array
bearings = np.degrees(np.arctan2(a[:,0], a[:,1])).reshape(-1,1)+90

print(bearings)
# Out:
# [[116.56505118]
#  [ 53.13010235]]

# %%
costs
# Out:
# array([[2.71828183],
#        [5.43656366],
#        [2.71828183],
#        [5.43656366]])

# %%
azimuth = np.array([[-1],[-1],[1],[1]])

# %%
v_cost_vectors =  costs * -1*azimuth
h_cost_vectors = costs * azimuth
cost_vectors = np.hstack([v_cost_vectors, h_cost_vectors])
cost_vectors
# Out:
# array([[ 2.71828183, -2.71828183],
#        [ 5.43656366, -5.43656366],
#        [-2.71828183,  2.71828183],
#        [-5.43656366,  5.43656366]])

# %%
geodesic.fwd(lats=1.36141933468784, lons=103.83210157865061, az=-90, dist=5*1000)
# Out:
# (103.78717321670398, 1.3614189134670607, 89.99893254652814)

# %%
import sys
sys.path.append('../')
import os
from onemap_client import OneMapClient

from dotenv import load_dotenv
load_dotenv()

email = os.environ['ONE_MAP_API_EMAIL']
password = os.environ['ONE_MAP_API_PASSWORD']

Client = OneMapClient(email, password)
token = Client.get_token(email, password)
print(token)

Client.get_route(
    start_coordinates =[1.3786507687752394, 103.85045573733659], 
    end_coordinates=[1.3766929439860232, 103.84829648589138], 
    route_type='drive'
)
# Out:
# ('eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..ivdt63sv_DgqRXaJ5BI7A6T6MsY91mQ8yU714Zskm20', 1701428718)
# {'status': 'error',
#  'message': 'Unable to get drive route: error: ST_Distance: Operation on mixed SRID geometries (Point, 0) != (Point, 4326)'}

# %%
Client.get_public_transport_route(
                start_coordinates=[1.320981,103.844150], 
                end_coordinates=[1.326762,103.8559], 
                date='01-14-2023',
                time='13:00:00',
                mode='TRANSIT'
            )
# Out:
# {'requestParameters': {'date': '01-14-2023',
#   'walkReluctance': '2',
#   'fromPlace': '1.320981,103.84415',
#   'transferPenalty': '7200',
#   'maxWalkDistance': '600',
#   'maxTransfers': '3',
#   'otherThanPreferredRoutesPenalty': '0',
#   'numItineraries': '3',
#   'mode': 'TRANSIT,WALK',
#   'arriveBy': 'false',
#   'showIntermediateStops': 'true',
#   'toPlace': '1.326762,103.8559',
#   'time': '1:00pm'},
#  'plan': {'date': 1673672400000,
#   'from': {'name': 'Origin',
#    'lon': 103.84415,
#    'lat': 1.320981,
#    'vertexType': 'NORMAL'},
#   'to': {'name': 'Destination',
#    'lon': 103.8559,
#    'lat': 1.326762,
#    'vertexType': 'NORMAL'},
#   'itineraries': [{'duration': 1025,
#     'startTime': 1673672646000,
#     'endTime': 1673673671000,
#     'walkTime': 487,
#     'transitTime': 538,
#     'waitingTime': 0,
#     'walkDistance': 553.62,
#     'walkLimitExceeded': False,
#     'generalizedCost': 2005,
#     'elevationLost': 0,
#     'elevationGained': 0,
#     'transfers': 0,
#     'fare': '0.99',
#     'legs': [{'startTime': 1673672646000,
#       'endTime': 1673673046000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 449.17,
#       'generalizedCost': 706,
#       'pathway': False,
#       'mode': 'WALK',
#       'transitLeg': False,
#       'route': '',
#       'agencyTimeZoneOffset': 28800000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': 'Origin',
#        'lon': 103.84415,
#        'lat': 1.320981,
#        'departure': 1673672646000,
#        'vertexType': 'NORMAL'},
#       'to': {'name': 'REVIVAL CTR CH',
#        'stopId': 'FERRY:50111',
#        'stopCode': '50111',
#        'lon': 103.846555,
#        'lat': 1.3187583,
#        'arrival': 1673673046000,
#        'departure': 1673673046000,
#        'vertexType': 'TRANSIT'},
#       'legGeometry': {'points': 's~`GmayxRa@a@VSDE@CFEHIPOBC@CA?@A\\Y@CnAmAHIBCDEDEDCDCJGFCJCFAHALAh@El@GXCXCF?TCAGC[?EB?JCPA@A@A?AEa@UaAAMB???',
#        'length': 47},
#       'steps': [{'distance': 449.17,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': 103.8442314,
#         'lat': 1.3209015,
#         'elevation': '',
#         'walkingBike': False}],
#       'rentedBike': False,
#       'walkingBike': False,
#       'duration': 400},
#      {'startTime': 1673673046000,
#       'endTime': 1673673584000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 2847.49,
#       'generalizedCost': 1138,
#       'pathway': False,
#       'mode': 'BUS',
#       'transitLeg': True,
#       'route': '124',
#       'agencyName': 'SBS Transit',
#       'agencyUrl': 'http://www.sbstransit.com.sg/',
#       'agencyTimeZoneOffset': 28800000,
#       'routeType': 3,
#       'routeId': '124',
#       'interlineWithPreviousLeg': False,
#       'agencyId': '1:SBST',
#       'tripId': '124-2-2031',
#       'serviceDate': '2023-01-14',
#       'from': {'name': 'REVIVAL CTR CH',
#        'stopId': 'FERRY:50111',
#        'stopCode': '50111',
#        'lon': 103.846555,
#        'lat': 1.3187583,
#        'arrival': 1673673046000,
#        'departure': 1673673046000,
#        'stopIndex': 36,
#        'stopSequence': 38,
#        'vertexType': 'TRANSIT'},
#       'to': {'name': "ST. MICHAEL'S TER",
#        'stopId': 'FERRY:52499',
#        'stopCode': '52499',
#        'lon': 103.8553721,
#        'lat': 1.3260376,
#        'arrival': 1673673584000,
#        'departure': 1673673584000,
#        'stopIndex': 42,
#        'stopSequence': 44,
#        'vertexType': 'TRANSIT'},
#       'intermediateStops': [{'name': 'NATL SKIN CTR',
#         'stopId': 'FERRY:50121',
#         'stopCode': '50121',
#         'lon': 103.8493392,
#         'lat': 1.319303,
#         'arrival': 1673673089000,
#         'departure': 1673673119000,
#         'stopIndex': 37,
#         'stopSequence': 39,
#         'vertexType': 'TRANSIT'},
#        {'name': 'OPP BLK 104',
#         'stopId': 'FERRY:50229',
#         'stopCode': '50229',
#         'lon': 103.8528349,
#         'lat': 1.3209576,
#         'arrival': 1673673191000,
#         'departure': 1673673221000,
#         'stopIndex': 38,
#         'stopSequence': 40,
#         'vertexType': 'TRANSIT'},
#        {'name': 'BLK 82',
#         'stopId': 'FERRY:50991',
#         'stopCode': '50991',
#         'lon': 103.8562615,
#         'lat': 1.3233799,
#         'arrival': 1673673307000,
#         'departure': 1673673337000,
#         'stopIndex': 39,
#         'stopSequence': 41,
#         'vertexType': 'TRANSIT'},
#        {'name': 'BLK 29',
#         'stopId': 'FERRY:52129',
#         'stopCode': '52129',
#         'lon': 103.8593811,
#         'lat': 1.3254467,
#         'arrival': 1673673409000,
#         'departure': 1673673439000,
#         'stopIndex': 40,
#         'stopSequence': 42,
#         'vertexType': 'TRANSIT'},
#        {'name': 'BET BLKS 33/34',
#         'stopId': 'FERRY:52109',
#         'stopCode': '52109',
#         'lon': 103.8581711,
#         'lat': 1.3269767,
#         'arrival': 1673673482000,
#         'departure': 1673673512000,
#         'stopIndex': 41,
#         'stopSequence': 43,
#         'vertexType': 'TRANSIT'}],
#       'legGeometry': {'points': 'ep`GcpyxRKaACQWuBMaASkBGc@Iy@OwA????OsAKmAKgAAs@Ae@AM@Q@w@BsCEo@O{@Qm@KSGKcCLM@{BL????kBJQ@qCN{@NKiFE}BAg@?I?C@OVk@H_@?e@CKEYQYOOoB}A??wAgA{BgBsB{AiAw@GKAODQj@s@j@s@@_A{AyA????m@k@UGS?YNq@|@o@x@qAhBi@t@????_AnAOTaARHl@[fDCb@OjB@JFHrCnAd@\\^Mh@w@jAv@',
#        'length': 86},
#       'steps': [],
#       'routeShortName': '124',
#       'routeLongName': 'SBST BUS 124',
#       'duration': 538,
#       'numIntermediateStops': 6},
#      {'startTime': 1673673584000,
#       'endTime': 1673673671000,
#       'departureDelay': 0,
#       'arrivalDelay': 0,
#       'realTime': False,
#       'distance': 104.45,
#       'generalizedCost': 161,
#       'pathway': False,
#       'mode': 'WALK',
#       'transitLeg': False,
#       'route': '',
#       'agencyTimeZoneOffset': 28800000,
#       'interlineWithPreviousLeg': False,
#       'from': {'name': "ST. MICHAEL'S TER",
#        'stopId': 'FERRY:52499',
#        'stopCode': '52499',
#        'lon': 103.8553721,
#        'lat': 1.3260376,
#        'arrival': 1673673584000,
#        'departure': 1673673584000,
#        'vertexType': 'TRANSIT'},
#       'to': {'name': 'Destination',
#        'lon': 103.8559,
#        'lat': 1.326762,
#        'arrival': 1673673671000,
#        'vertexType': 'NORMAL'},
#       'legGeometry': {'points': 'u~aGag{xR??BEYQk@a@GE[IOKMIMI', 'length': 10},
#       'steps': [{'distance': 104.46,
#         'relativeDirection': 'DEPART',
#         'streetName': 'path',
#         'absoluteDirection': 'NORTHEAST',
#         'stayOn': False,
#         'area': False,
#         'bogusName': True,
#         'lon': 103.8553721,
#         'lat': 1.3260375,
#         'elevation': '',
#         'walkingBike': False}],
#       'rentedBike': False,
#       'walkingBike': False,
#       'duration': 87}],
#     'tooSloped': False,
#     'arrivedAtDestinationWithRentedBicycle': False}]},
#  'metadata': {'searchWindowUsed': 3000,
#   'nextDateTime': 1673674020000,
#   'prevDateTime': 1673669400000},
#  'previousPageCursor': 'rO0ABXc1AQANUFJFVklPVVNfUEFHRQW2THCAAAAAAAAJYAAXU1RSRUVUX0FORF9BUlJJVkFMX1RJTUU=',
#  'nextPageCursor': 'rO0ABXcxAQAJTkVYVF9QQUdFBbZcJIAAAAAAAAlgABdTVFJFRVRfQU5EX0FSUklWQUxfVElNRQ==',
#  'debugOutput': {'precalculationTime': 25420,
#   'directStreetRouterTime': 6210832,
#   'transitRouterTime': 251607027,
#   'filteringTime': 856134,
#   'renderingTime': 899754,
#   'totalTime': 259614322,
#   'transitRouterTimes': {'tripPatternFilterTime': 27271776,
#    'accessEgressTime': 54376337,
#    'raptorSearchTime': 164467088,
#    'itineraryCreationTime': 5475179}},
#  'elevationMetadata': {'ellipsoidToGeoidDifference': 7.473035522254212,
#   'geoidElevation': False}}

# %%
import requests
      
url = "https://www.onemap.gov.sg/api/public/routingsvc/route?start=1.319728%2C103.8421&end=1.319728905%2C103.8421581&routeType=drive"
      
headers = {"Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..ivdt63sv_DgqRXaJ5BI7A6T6MsY91mQ8yU714Zskm20"}
      
response = requests.request("GET", url, headers=headers)
      
print(response)
# Out:
# <Response [404]>

# %%
import requests
      
url = "https://www.onemap.gov.sg/api/public/routingsvc/route?start=1.320981%2C103.844150&end=1.326762%2C103.8559&routeType=pt&date=08-13-2023&time=07%3A35%3A00&mode=TRANSIT&maxWalkDistance=1000&numItineraries=3"
      
headers = {"Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..ivdt63sv_DgqRXaJ5BI7A6T6MsY91mQ8yU714Zskm20"}
         
response = requests.request("GET", url, headers=headers)
      
print(response.text)
# Out:
# {
#   "requestParameters": {
#     "date": "12-13-2023",
#     "walkReluctance": "2",
#     "fromPlace": "1.320981,103.844150",
#     "transferPenalty": "7200",
#     "maxWalkDistance": "1000",
#     "maxTransfers": "3",
#     "otherThanPreferredRoutesPenalty": "0",
#     "numItineraries": "3",
#     "mode": "TRANSIT,WALK",
#     "arriveBy": "false",
#     "showIntermediateStops": "true",
#     "toPlace": "1.326762,103.8559",
#     "time": "7:35am"
#   },
#   "plan": {
#     "date": 1702424100000,
#     "from": {
#       "name": "Origin",
#       "lon": 103.84415,
#       "lat": 1.320981,
#       "vertexType": "NORMAL"
#     },
#     "to": {
#       "name": "Destination",
#       "lon": 103.8559,
#       "lat": 1.326762,
#       "vertexType": "NORMAL"
#     },
#     "itineraries": [
#       {
#         "duration": 1025,
#         "startTime": 1702424346000,
#         "endTime": 1702425371000,
#         "walkTime": 487,
#         "transitTime": 538,
#         "waitingTime": 0,
#         "walkDistance": 553.62,
#         "walkLimitExceeded": false,
#         "generalizedCost": 2005,
#         "elevationLost": 0,
#         "elevationGained": 0,
#         "transfers": 0,
#         "fare": "0.99",
#         "legs": [
#           {
#             "startTime": 1702424346000,
#             "endTime": 1702424746000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 449.17,
#             "generalizedCost": 706,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "Origin",
#               "lon": 103.84415,
#               "lat": 1.320981,
#               "departure": 1702424346000,
#               "vertexType": "NORMAL"
#             },
#             "to": {
#               "name": "REVIVAL CTR CH",
#               "stopId": "FERRY:50111",
#               "stopCode": "50111",
#               "lon": 103.846555,
#               "lat": 1.3187583,
#               "arrival": 1702424746000,
#               "departure": 1702424746000,
#               "vertexType": "TRANSIT"
#             },
#             "legGeometry": {
#               "points": "s~`GmayxRa@a@VSDE@CFEHIPOBC@CA?@A\\Y@CnAmAHIBCDEDEDCDCJGFCJCFAHALAh@El@GXCXCF?TCAGC[?EB?JCPA@A@A?AEa@UaAAMB???",
#               "length": 47
#             },
#             "steps": [
#               {
#                 "distance": 449.17,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "NORTHEAST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8442314,
#                 "lat": 1.3209015,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 400
#           },
#           {
#             "startTime": 1702424746000,
#             "endTime": 1702425284000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 2847.49,
#             "generalizedCost": 1138,
#             "pathway": false,
#             "mode": "BUS",
#             "transitLeg": true,
#             "route": "124",
#             "agencyName": "SBS Transit",
#             "agencyUrl": "http://www.sbstransit.com.sg/",
#             "agencyTimeZoneOffset": 28800000,
#             "routeType": 3,
#             "routeId": "124",
#             "interlineWithPreviousLeg": false,
#             "agencyId": "1:SBST",
#             "tripId": "124-2-1004",
#             "serviceDate": "2023-12-13",
#             "from": {
#               "name": "REVIVAL CTR CH",
#               "stopId": "FERRY:50111",
#               "stopCode": "50111",
#               "lon": 103.846555,
#               "lat": 1.3187583,
#               "arrival": 1702424746000,
#               "departure": 1702424746000,
#               "stopIndex": 36,
#               "stopSequence": 38,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425284000,
#               "departure": 1702425284000,
#               "stopIndex": 42,
#               "stopSequence": 44,
#               "vertexType": "TRANSIT"
#             },
#             "intermediateStops": [
#               {
#                 "name": "NATL SKIN CTR",
#                 "stopId": "FERRY:50121",
#                 "stopCode": "50121",
#                 "lon": 103.8493392,
#                 "lat": 1.319303,
#                 "arrival": 1702424789000,
#                 "departure": 1702424819000,
#                 "stopIndex": 37,
#                 "stopSequence": 39,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "OPP BLK 104",
#                 "stopId": "FERRY:50229",
#                 "stopCode": "50229",
#                 "lon": 103.8528349,
#                 "lat": 1.3209576,
#                 "arrival": 1702424891000,
#                 "departure": 1702424921000,
#                 "stopIndex": 38,
#                 "stopSequence": 40,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 82",
#                 "stopId": "FERRY:50991",
#                 "stopCode": "50991",
#                 "lon": 103.8562615,
#                 "lat": 1.3233799,
#                 "arrival": 1702425007000,
#                 "departure": 1702425037000,
#                 "stopIndex": 39,
#                 "stopSequence": 41,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 29",
#                 "stopId": "FERRY:52129",
#                 "stopCode": "52129",
#                 "lon": 103.8593811,
#                 "lat": 1.3254467,
#                 "arrival": 1702425109000,
#                 "departure": 1702425139000,
#                 "stopIndex": 40,
#                 "stopSequence": 42,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BET BLKS 33/34",
#                 "stopId": "FERRY:52109",
#                 "stopCode": "52109",
#                 "lon": 103.8581711,
#                 "lat": 1.3269767,
#                 "arrival": 1702425182000,
#                 "departure": 1702425212000,
#                 "stopIndex": 41,
#                 "stopSequence": 43,
#                 "vertexType": "TRANSIT"
#               }
#             ],
#             "legGeometry": {
#               "points": "ep`GcpyxRKaACQWuBMaASkBGc@Iy@OwA????OsAKmAKgAAs@Ae@AM@Q@w@BsCEo@O{@Qm@KSGKcCLM@{BL????kBJQ@qCN{@NKiFE}BAg@?I?C@OVk@H_@?e@CKEYQYOOoB}A??wAgA{BgBsB{AiAw@GKAODQj@s@j@s@@_A{AyA????m@k@UGS?YNq@|@o@x@qAhBi@t@????_AnAOTaARHl@[fDCb@OjB@JFHrCnAd@\\^Mh@w@jAv@",
#               "length": 86
#             },
#             "steps": [],
#             "routeShortName": "124",
#             "routeLongName": "SBST BUS 124",
#             "duration": 538,
#             "numIntermediateStops": 6
#           },
#           {
#             "startTime": 1702425284000,
#             "endTime": 1702425371000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 104.45,
#             "generalizedCost": 161,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425284000,
#               "departure": 1702425284000,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "Destination",
#               "lon": 103.8559,
#               "lat": 1.326762,
#               "arrival": 1702425371000,
#               "vertexType": "NORMAL"
#             },
#             "legGeometry": {
#               "points": "u~aGag{xR??BEYQk@a@GE[IOKMIMI",
#               "length": 10
#             },
#             "steps": [
#               {
#                 "distance": 104.46,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "NORTHEAST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8553721,
#                 "lat": 1.3260375,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 87
#           }
#         ],
#         "tooSloped": false,
#         "arrivedAtDestinationWithRentedBicycle": false
#       },
#       {
#         "duration": 1188,
#         "startTime": 1702424513000,
#         "endTime": 1702425701000,
#         "walkTime": 345,
#         "transitTime": 698,
#         "waitingTime": 145,
#         "walkDistance": 392.72,
#         "walkLimitExceeded": false,
#         "generalizedCost": 2667,
#         "elevationLost": 0,
#         "elevationGained": 0,
#         "transfers": 1,
#         "fare": "1.09",
#         "legs": [
#           {
#             "startTime": 1702424513000,
#             "endTime": 1702424689000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 201.98,
#             "generalizedCost": 323,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "Origin",
#               "lon": 103.84415,
#               "lat": 1.320981,
#               "departure": 1702424513000,
#               "vertexType": "NORMAL"
#             },
#             "to": {
#               "name": "NOVENA STN",
#               "stopId": "FERRY:50038",
#               "stopCode": "50038",
#               "lon": 103.8429865,
#               "lat": 1.320174,
#               "arrival": 1702424689000,
#               "departure": 1702424689000,
#               "vertexType": "TRANSIT"
#             },
#             "legGeometry": {
#               "points": "s~`GmayxRp@p@ZXRR[XhBfBUNBBIDAA",
#               "length": 10
#             },
#             "steps": [
#               {
#                 "distance": 201.98,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "SOUTHWEST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8442314,
#                 "lat": 1.3209015,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 176
#           },
#           {
#             "startTime": 1702424689000,
#             "endTime": 1702424936000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 1448.95,
#             "generalizedCost": 847,
#             "pathway": false,
#             "mode": "BUS",
#             "transitLeg": true,
#             "route": "21",
#             "agencyName": "SBS Transit",
#             "agencyUrl": "http://www.sbstransit.com.sg/",
#             "agencyTimeZoneOffset": 28800000,
#             "routeType": 3,
#             "routeId": "21",
#             "interlineWithPreviousLeg": false,
#             "agencyId": "1:SBST",
#             "tripId": "21-2-1007",
#             "serviceDate": "2023-12-13",
#             "from": {
#               "name": "NOVENA STN",
#               "stopId": "FERRY:50038",
#               "stopCode": "50038",
#               "lon": 103.8429865,
#               "lat": 1.320174,
#               "arrival": 1702424689000,
#               "departure": 1702424689000,
#               "stopIndex": 14,
#               "stopSequence": 15,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "NORTHLIGHT SCH",
#               "stopId": "FERRY:50231",
#               "stopCode": "50231",
#               "lon": 103.8549258,
#               "lat": 1.3187247,
#               "arrival": 1702424936000,
#               "departure": 1702424936000,
#               "stopIndex": 17,
#               "stopSequence": 18,
#               "vertexType": "TRANSIT"
#             },
#             "intermediateStops": [
#               {
#                 "name": "REVIVAL CTR CH",
#                 "stopId": "FERRY:50111",
#                 "stopCode": "50111",
#                 "lon": 103.846555,
#                 "lat": 1.3187583,
#                 "arrival": 1702424747000,
#                 "departure": 1702424777000,
#                 "stopIndex": 15,
#                 "stopSequence": 16,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "NATL SKIN CTR",
#                 "stopId": "FERRY:50121",
#                 "stopCode": "50121",
#                 "lon": 103.8493392,
#                 "lat": 1.319303,
#                 "arrival": 1702424820000,
#                 "departure": 1702424850000,
#                 "stopIndex": 16,
#                 "stopSequence": 17,
#                 "vertexType": "TRANSIT"
#               }
#             ],
#             "legGeometry": {
#               "points": "my`GyxxxR@AROz@o@nA}@v@q@d@kAn@_CXkCGaAAYCQSqB????AEI{@CQWuBMaAGg@E_@Ec@Gc@?ACYE]K{@AQAC?E????OsAKmAAKI{@As@AQ?Q?AAM@Q?C@Y?YBsCEo@O{@K]EOEIEIGKJ]?ABIDIFKJS@A@C\\o@N[`@u@DIJSBEFMLUTe@DKDG",
#               "length": 73
#             },
#             "steps": [],
#             "routeShortName": "21",
#             "routeLongName": "SBST BUS 21",
#             "duration": 247,
#             "numIntermediateStops": 3
#           },
#           {
#             "startTime": 1702424936000,
#             "endTime": 1702425018000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 86.29,
#             "generalizedCost": 139,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "NORTHLIGHT SCH",
#               "stopId": "FERRY:50231",
#               "stopCode": "50231",
#               "lon": 103.8549258,
#               "lat": 1.3187247,
#               "arrival": 1702424936000,
#               "departure": 1702424936000,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "S'PORE INDIAN ASSN",
#               "stopId": "FERRY:50239",
#               "stopCode": "50239",
#               "lon": 103.8552164,
#               "lat": 1.3182729,
#               "arrival": 1702425018000,
#               "departure": 1702425163000,
#               "vertexType": "TRANSIT"
#             },
#             "legGeometry": {
#               "points": "_q`Ggd{xR??AA?CDE?APSh@Z??@EBIFM??HMBC@ACA",
#               "length": 17
#             },
#             "steps": [
#               {
#                 "distance": 86.29,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "NORTHEAST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8549258,
#                 "lat": 1.3187247,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 82
#           },
#           {
#             "startTime": 1702425163000,
#             "endTime": 1702425614000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 2388.66,
#             "generalizedCost": 1196,
#             "pathway": false,
#             "mode": "BUS",
#             "transitLeg": true,
#             "route": "125",
#             "agencyName": "SBS Transit",
#             "agencyUrl": "http://www.sbstransit.com.sg/",
#             "agencyTimeZoneOffset": 28800000,
#             "routeType": 3,
#             "routeId": "125",
#             "interlineWithPreviousLeg": false,
#             "agencyId": "1:SBST",
#             "tripId": "125-1-1003",
#             "serviceDate": "2023-12-13",
#             "from": {
#               "name": "S'PORE INDIAN ASSN",
#               "stopId": "FERRY:50239",
#               "stopCode": "50239",
#               "lon": 103.8552164,
#               "lat": 1.3182729,
#               "arrival": 1702425018000,
#               "departure": 1702425163000,
#               "stopIndex": 42,
#               "stopSequence": 46,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425614000,
#               "departure": 1702425614000,
#               "stopIndex": 47,
#               "stopSequence": 51,
#               "vertexType": "TRANSIT"
#             },
#             "intermediateStops": [
#               {
#                 "name": "OPP BLK 104",
#                 "stopId": "FERRY:50229",
#                 "stopCode": "50229",
#                 "lon": 103.8528349,
#                 "lat": 1.3209576,
#                 "arrival": 1702425221000,
#                 "departure": 1702425251000,
#                 "stopIndex": 43,
#                 "stopSequence": 47,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 82",
#                 "stopId": "FERRY:50991",
#                 "stopCode": "50991",
#                 "lon": 103.8562615,
#                 "lat": 1.3233799,
#                 "arrival": 1702425337000,
#                 "departure": 1702425367000,
#                 "stopIndex": 44,
#                 "stopSequence": 48,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 29",
#                 "stopId": "FERRY:52129",
#                 "stopCode": "52129",
#                 "lon": 103.8593811,
#                 "lat": 1.3254467,
#                 "arrival": 1702425439000,
#                 "departure": 1702425469000,
#                 "stopIndex": 45,
#                 "stopSequence": 49,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BET BLKS 33/34",
#                 "stopId": "FERRY:52109",
#                 "stopCode": "52109",
#                 "lon": 103.8581711,
#                 "lat": 1.3269767,
#                 "arrival": 1702425512000,
#                 "departure": 1702425542000,
#                 "stopIndex": 46,
#                 "stopSequence": 50,
#                 "vertexType": "TRANSIT"
#               }
#             ],
#             "legGeometry": {
#               "points": "sn`Gkf{xRINCDe@|@KPUd@MTIJCFIRg@~@m@jAAB?@MTGJEDCJ?@K\\e@BK@a@@m@De@DeBH????E?sAHQ@Q@qCN{@PKkFE}BAq@@STk@J_@?e@CKGYOWOQiByAEC????uAgAqFcEKG_Ao@EKAOFSh@q@j@s@@Y?c@wAuACC???Am@k@UGS?YNq@|@o@x@qAhBi@t@????_AnAOTaARHl@[fDCb@QfB@B@JFHrCnAd@\\^Mh@w@jAv@",
#               "length": 89
#             },
#             "steps": [],
#             "routeShortName": "125",
#             "routeLongName": "SBST BUS 125",
#             "duration": 451,
#             "numIntermediateStops": 5
#           },
#           {
#             "startTime": 1702425614000,
#             "endTime": 1702425701000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 104.45,
#             "generalizedCost": 161,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425614000,
#               "departure": 1702425614000,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "Destination",
#               "lon": 103.8559,
#               "lat": 1.326762,
#               "arrival": 1702425701000,
#               "vertexType": "NORMAL"
#             },
#             "legGeometry": {
#               "points": "u~aGag{xR??BEYQk@a@GE[IOKMIMI",
#               "length": 10
#             },
#             "steps": [
#               {
#                 "distance": 104.46,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "NORTHEAST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8553721,
#                 "lat": 1.3260375,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 87
#           }
#         ],
#         "tooSloped": false,
#         "arrivedAtDestinationWithRentedBicycle": false
#       },
#       {
#         "duration": 1256,
#         "startTime": 1702424475000,
#         "endTime": 1702425731000,
#         "walkTime": 468,
#         "transitTime": 788,
#         "waitingTime": 0,
#         "walkDistance": 534.39,
#         "walkLimitExceeded": false,
#         "generalizedCost": 2228,
#         "elevationLost": 0,
#         "elevationGained": 0,
#         "transfers": 0,
#         "fare": "1.09",
#         "legs": [
#           {
#             "startTime": 1702424475000,
#             "endTime": 1702424856000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 429.94,
#             "generalizedCost": 678,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "Origin",
#               "lon": 103.84415,
#               "lat": 1.320981,
#               "departure": 1702424475000,
#               "vertexType": "NORMAL"
#             },
#             "to": {
#               "name": "OPP NOVENA CH",
#               "stopId": "FERRY:50031",
#               "stopCode": "50031",
#               "lon": 103.8417717,
#               "lat": 1.3212731,
#               "arrival": 1702424856000,
#               "departure": 1702424856000,
#               "vertexType": "TRANSIT"
#             },
#             "legGeometry": {
#               "points": "s~`GmayxRp@p@ZXRR[X]^Xp@j@lAIJc@ZIFGFSNIDEBIDGHSJIFKDCBYRIHSHKEEB@@EBd@r@?ADAB?BBHECG??",
#               "length": 36
#             },
#             "steps": [
#               {
#                 "distance": 429.94,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "SOUTHWEST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8442314,
#                 "lat": 1.3209015,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 381
#           },
#           {
#             "startTime": 1702424856000,
#             "endTime": 1702425644000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 4759.31,
#             "generalizedCost": 1388,
#             "pathway": false,
#             "mode": "BUS",
#             "transitLeg": true,
#             "route": "131",
#             "agencyName": "SBS Transit",
#             "agencyUrl": "http://www.sbstransit.com.sg/",
#             "agencyTimeZoneOffset": 28800000,
#             "routeType": 3,
#             "routeId": "131",
#             "interlineWithPreviousLeg": false,
#             "agencyId": "1:SBST",
#             "tripId": "131-2-1003",
#             "serviceDate": "2023-12-13",
#             "from": {
#               "name": "OPP NOVENA CH",
#               "stopId": "FERRY:50031",
#               "stopCode": "50031",
#               "lon": 103.8417717,
#               "lat": 1.3212731,
#               "arrival": 1702424856000,
#               "departure": 1702424856000,
#               "stopIndex": 37,
#               "stopSequence": 38,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425644000,
#               "departure": 1702425644000,
#               "stopIndex": 47,
#               "stopSequence": 48,
#               "vertexType": "TRANSIT"
#             },
#             "intermediateStops": [
#               {
#                 "name": "NOVENA LODGE",
#                 "stopId": "FERRY:50041",
#                 "stopCode": "50041",
#                 "lon": 103.8416155,
#                 "lat": 1.3236233,
#                 "arrival": 1702424899000,
#                 "departure": 1702424929000,
#                 "stopIndex": 38,
#                 "stopSequence": 39,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BEF JLN DUSUN",
#                 "stopId": "FERRY:50161",
#                 "stopCode": "50161",
#                 "lon": 103.8436601,
#                 "lat": 1.326657,
#                 "arrival": 1702425001000,
#                 "departure": 1702425031000,
#                 "stopIndex": 39,
#                 "stopSequence": 40,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "ZHONGSHAN MALL",
#                 "stopId": "FERRY:50171",
#                 "stopCode": "50171",
#                 "lon": 103.84641,
#                 "lat": 1.3266339,
#                 "arrival": 1702425074000,
#                 "departure": 1702425104000,
#                 "stopIndex": 40,
#                 "stopSequence": 41,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BEF BALESTIER PLAZA",
#                 "stopId": "FERRY:50191",
#                 "stopCode": "50191",
#                 "lon": 103.8490239,
#                 "lat": 1.326045,
#                 "arrival": 1702425148000,
#                 "departure": 1702425178000,
#                 "stopIndex": 41,
#                 "stopSequence": 42,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "SHAW PLAZA",
#                 "stopId": "FERRY:50201",
#                 "stopCode": "50201",
#                 "lon": 103.8509656,
#                 "lat": 1.3249047,
#                 "arrival": 1702425206000,
#                 "departure": 1702425236000,
#                 "stopIndex": 42,
#                 "stopSequence": 43,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "OPP BALESTIER PT",
#                 "stopId": "FERRY:50211",
#                 "stopCode": "50211",
#                 "lon": 103.8525671,
#                 "lat": 1.3230697,
#                 "arrival": 1702425280000,
#                 "departure": 1702425310000,
#                 "stopIndex": 43,
#                 "stopSequence": 44,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 82",
#                 "stopId": "FERRY:50991",
#                 "stopCode": "50991",
#                 "lon": 103.8562615,
#                 "lat": 1.3233799,
#                 "arrival": 1702425367000,
#                 "departure": 1702425397000,
#                 "stopIndex": 44,
#                 "stopSequence": 45,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BLK 29",
#                 "stopId": "FERRY:52129",
#                 "stopCode": "52129",
#                 "lon": 103.8593811,
#                 "lat": 1.3254467,
#                 "arrival": 1702425469000,
#                 "departure": 1702425499000,
#                 "stopIndex": 45,
#                 "stopSequence": 46,
#                 "vertexType": "TRANSIT"
#               },
#               {
#                 "name": "BET BLKS 33/34",
#                 "stopId": "FERRY:52109",
#                 "stopCode": "52109",
#                 "lon": 103.8581711,
#                 "lat": 1.3269767,
#                 "arrival": 1702425542000,
#                 "departure": 1702425572000,
#                 "stopIndex": 46,
#                 "stopSequence": 47,
#                 "vertexType": "TRANSIT"
#               }
#             ],
#             "legGeometry": {
#               "points": "kaaG_sxxR@?JEHE@?DC`@U??FERKf@a@h@a@|BcBr@g@JIp@g@v@q@`@Qv@_@tA]HAr@Q??fAUDAsWfNWJc@LwA^W@K?k@?uAI_@CEAu@GMA_@C??C?iBOcAKMAcBKeAC_ABm@De@Je@JI@AMGcBK_CEqACk@????Eu@?SEuAFaA@WJ_B?aACiC??EaC?Y?q@@q@x@aC~@}B????Tk@n@cBL_@JWNa@Tc@`@e@d@i@V[????fAoAl@m@RQ~@q@POVU^YnAaA????DEbAi@KiFE}BAg@?I?C@OVk@H_@?e@CKEYQYOOoB}A??wAgA{BgBsB{AiAw@GKAODQj@s@j@s@@_A{AyA????m@k@UGS?YNq@|@o@x@qAhBi@t@????_AnAOTaARHl@[fDCb@OjB@JFHrCnAd@\\^Mh@w@jAv@",
#               "length": 149
#             },
#             "steps": [],
#             "routeShortName": "131",
#             "routeLongName": "SBST BUS 131",
#             "duration": 788,
#             "numIntermediateStops": 10
#           },
#           {
#             "startTime": 1702425644000,
#             "endTime": 1702425731000,
#             "departureDelay": 0,
#             "arrivalDelay": 0,
#             "realTime": false,
#             "distance": 104.45,
#             "generalizedCost": 161,
#             "pathway": false,
#             "mode": "WALK",
#             "transitLeg": false,
#             "route": "",
#             "agencyTimeZoneOffset": 28800000,
#             "interlineWithPreviousLeg": false,
#             "from": {
#               "name": "ST. MICHAEL'S TER",
#               "stopId": "FERRY:52499",
#               "stopCode": "52499",
#               "lon": 103.8553721,
#               "lat": 1.3260376,
#               "arrival": 1702425644000,
#               "departure": 1702425644000,
#               "vertexType": "TRANSIT"
#             },
#             "to": {
#               "name": "Destination",
#               "lon": 103.8559,
#               "lat": 1.326762,
#               "arrival": 1702425731000,
#               "vertexType": "NORMAL"
#             },
#             "legGeometry": {
#               "points": "u~aGag{xR??BEYQk@a@GE[IOKMIMI",
#               "length": 10
#             },
#             "steps": [
#               {
#                 "distance": 104.46,
#                 "relativeDirection": "DEPART",
#                 "streetName": "path",
#                 "absoluteDirection": "NORTHEAST",
#                 "stayOn": false,
#                 "area": false,
#                 "bogusName": true,
#                 "lon": 103.8553721,
#                 "lat": 1.3260375,
#                 "elevation": "",
#                 "walkingBike": false
#               }
#             ],
#             "rentedBike": false,
#             "walkingBike": false,
#             "duration": 87
#           }
#         ],
#         "tooSloped": false,
#         "arrivedAtDestinationWithRentedBicycle": false
#       }
#     ]
#   },
#   "metadata": {
#     "searchWindowUsed": 3000,
#     "nextDateTime": 1702424820000,
#     "prevDateTime": 1702421100000
#   },
#   "previousPageCursor": "rO0ABXc1AQANUFJFVklPVVNfUEFHRQdtA8SAAAAAAAAJYAAXU1RSRUVUX0FORF9BUlJJVkFMX1RJTUU=",
#   "nextPageCursor": "rO0ABXcxAQAJTkVYVF9QQUdFB20P9IAAAAAAAAlgABdTVFJFRVRfQU5EX0FSUklWQUxfVElNRQ==",
#   "debugOutput": {
#     "precalculationTime": 24805,
#     "directStreetRouterTime": 8000305,
#     "transitRouterTime": 389597716,
#     "filteringTime": 846099,
#     "renderingTime": 218284,
#     "totalTime": 398699726,
#     "transitRouterTimes": {
#       "tripPatternFilterTime": 40821929,
#       "accessEgressTime": 65442496,
#       "raptorSearchTime": 276938611,
#       "itineraryCreationTime": 6378632
#     }
#   },
#   "elevationMetadata": {
#     "ellipsoidToGeoidDifference": 7.473035522254212,
#     "geoidElevation": false
#   }
# }

# %%
resultant_cost_vectors = np.array([[-1.19523865,0.66428467]])

# %%
np.degrees(np.arctan2(resultant_cost_vectors[:,0], resultant_cost_vectors[:,1])).reshape(-1,1)+90
# Out:
# array([[29.06424436]])

# %%
np.degrees(np.arctan2(resultant_cost_vectors[:,0], resultant_cost_vectors[:,1])).reshape(-1,1)+90
# Out:
# array([[-60.93575564]])

# %%
v = -1.19523865
h = -0.66428467

# %%
np.degrees(np.arctan2(h, v))
# Out:
# -150.93575564031786

# %%
import folium

# %%
coors =  [[1.3193790935628127, 103.82903068459888], [1.356772075222052, 103.79696381492978], [1.3577535204191273, 103.8689502597439], [1.3585991366700532, 103.82418638183557], [1.3978697200051884, 103.82475361410458], [1.327586913808211, 103.82525781941514], [1.356088080540262, 103.80592373172115], [1.3590184107441585, 103.86005292254282], [1.3607951911598795, 103.81546966369723], [1.3940769179579147, 103.81659624290974], [1.3332066585391096, 103.81821771090041], [1.3552965488240303, 103.8148749000832], [1.3603196561478315, 103.85116075784266], [1.3629866158545918, 103.80675178747822], [1.3866605022617986, 103.8217384793293], [1.3385783484574036, 103.81098895418192], [1.3585678272897057, 103.80649769643551], [1.3615289376958002, 103.84225578159628], [1.3651581015632206, 103.79802897927871], [1.3843686983916998, 103.81304603572472], [1.3458650335840432, 103.80566686604716], [1.3626205126416155, 103.83333580164654], [1.3672856792096468, 103.78929548800059], [1.3825272587474529, 103.80424852719037], [1.3524265119206746, 103.79948308747836], [1.3636914793516919, 103.82441335187363], [1.3655897082659072, 103.79812175960559], [1.3811527070080543, 103.79536717608906], [1.3521432440109575, 103.80846431723309], [1.364879173235534, 103.81550549547346], [1.3676320717777737, 103.7893682064449], [1.3662387384020143, 103.80662192740253], [1.3658959731067113, 103.7981867737696], [1.3678777718587944, 103.78941948688252], [1.3678310150991506, 103.79777660516429], [1.3694599110490622, 103.78893786206866], [1.3661132349693432, 103.79823248095015]]

m = folium.Map(
    location=(1.3674754117016408, 103.81093951150724), 
    zoom_start=11,
    min_zoom=11
)

for i, coor in enumerate(coors):
    m.add_child(
        folium.Marker(
            location = coor,
            tooltip=i
        )
    )
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dab9d5b03ed0a35d9f3e3c412803b83e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dab9d5b03ed0a35d9f3e3c412803b83e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dab9d5b03ed0a35d9f3e3c412803b83e = L.map(
#                 &quot;map_dab9d5b03ed0a35d9f3e3c412803b83e&quot;,
#                 {
#                     center: [1.3674754117016408, 103.81093951150724],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45b4975be8f3d72ad17c2d2dbe9dcc33 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 11, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             var marker_b7e12e77930f99c04214322ac318145d = L.marker(
#                 [1.3193790935628127, 103.82903068459888],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_b7e12e77930f99c04214322ac318145d.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_59214c96fedc67d5f152c8446cacf0f2 = L.marker(
#                 [1.356772075222052, 103.79696381492978],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_59214c96fedc67d5f152c8446cacf0f2.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a7043424775b4faa77e08843252b832f = L.marker(
#                 [1.3577535204191273, 103.8689502597439],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_a7043424775b4faa77e08843252b832f.bindTooltip(
#                 `&lt;div&gt;
#                      2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5fa3ba734b345a79a85c963a70bb7bfb = L.marker(
#                 [1.3585991366700532, 103.82418638183557],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_5fa3ba734b345a79a85c963a70bb7bfb.bindTooltip(
#                 `&lt;div&gt;
#                      3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2f4a6f633edd092502a45036216c5c0d = L.marker(
#                 [1.3978697200051884, 103.82475361410458],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_2f4a6f633edd092502a45036216c5c0d.bindTooltip(
#                 `&lt;div&gt;
#                      4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40202d7104a18e47c8253fa5fb1282bd = L.marker(
#                 [1.327586913808211, 103.82525781941514],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_40202d7104a18e47c8253fa5fb1282bd.bindTooltip(
#                 `&lt;div&gt;
#                      5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9cc7e62c9125aee042467ae84e687cf0 = L.marker(
#                 [1.356088080540262, 103.80592373172115],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_9cc7e62c9125aee042467ae84e687cf0.bindTooltip(
#                 `&lt;div&gt;
#                      6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d94968de4e5f6ca0d53d6244fa9c5726 = L.marker(
#                 [1.3590184107441585, 103.86005292254282],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_d94968de4e5f6ca0d53d6244fa9c5726.bindTooltip(
#                 `&lt;div&gt;
#                      7
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_518f24e4252ea086557fb018ad557289 = L.marker(
#                 [1.3607951911598795, 103.81546966369723],
#                 {}
#             ).addTo(map_dab9d5b03ed0a35d9f3e3c412803b83e);
#
#
#             marker_518f24e4252ea086557fb018ad557289.bindTooltip(
#                 `&lt;div&gt;
#                      8
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52ab2b9b04911bb52730b35debb7c647 = L.marker(
#                 [1.3940769179579147, 103.816596242

# %%
import numpy as np

a = np.array([[-1],[-1],[-1],[-1]])
b = np.array([[0],[1],[2],[3]])

# Create a boolean mask where True corresponds to elements in 'a' that are not -1
mask = a != [-1]

mask = np.all(mask, axis=1)
# Use the mask to index into 'b'
result = b[mask]

print(result)
# Out:
# []

# %%
mask
# Out:
# array([False, False, False, False])

# %%
np.any(mask)
# Out:
# False

# %%
np.unique(expand_search_array, axis=0)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
cost_vectors = np.array([[ 28.86319184, -17.96608517],
 [-1.00790728,11.89721101],
 [3.90371043,-26.26883033],
 [ -0.42292976,  -1.62547499]])

# %%
np.degrees(np.arctan2(cost_vectors[:,1], cost_vectors[:,0])).reshape(-1,1)
# Out:
# array([[ -31.90047291],
#        [  94.84241796],
#        [ -81.54735322],
#        [-104.58432752]])
