# %%
import pandas as pd

# %%
data = pd.read_csv('./data/processed/202311292041/property_amenities.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84617 entries, 0 to 84616
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   property_id   84617 non-null  int64
#  1   amenity_type  84617 non-null  object
#  2   amenity_name  84617 non-null  object
#  3   latitude      84617 non-null  float64
#  4   longitude     84617 non-null  float64
#  5   distance_km   84617 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 3.9+ MB

# %%
temp = data.groupby(by=['property_id', 'amenity_type','amenity_name','latitude','longitude'])['distance_km'].count().reset_index()

temp[temp['distance_km']>1]
# Out:
#        property_id  amenity_type amenity_name  latitude   longitude  \
# 59        20090682  cycling_path     Clementi  1.316440  103.765047
# 61        20090682  cycling_path     Clementi  1.317859  103.765901
# 63        20090682  cycling_path     Clementi  1.318470  103.765855
# 65        20090682  cycling_path     Clementi  1.318711  103.765919
# 67        20090682  cycling_path     Clementi  1.319475  103.766245
# ...            ...           ...          ...       ...         ...
# 82524     24841369  cycling_path        Bedok  1.331041  103.925755
# 82540     24841369  cycling_path        Bedok  1.331630  103.930464
# 83052     24841373  cycling_path        Bedok  1.322973  103.923367
# 83096     24841373  cycling_path        Bedok  1.326919  103.925421
# 83153     24841373  cycling_path        Bedok  1.331041  103.925755
#
#        distance_km
# 59               2
# 61               2
# 63               2
# 65               2
# 67               2
# ...            ...
# ...

# %%
data[(data['property_id']==20090682)&(data['amenity_type']=='cycling_path')&(data['amenity_name']=='Clementi')]
# Out:
#        property_id  amenity_type amenity_name  latitude   longitude  \
# 54937     20090682  cycling_path     Clementi  1.316440  103.765047
# 54938     20090682  cycling_path     Clementi  1.316440  103.765047
# 54939     20090682  cycling_path     Clementi  1.317859  103.765901
# 54940     20090682  cycling_path     Clementi  1.317859  103.765901
# 54941     20090682  cycling_path     Clementi  1.318470  103.765855
# 54942     20090682  cycling_path     Clementi  1.318470  103.765855
# 54943     20090682  cycling_path     Clementi  1.318711  103.765919
# 54944     20090682  cycling_path     Clementi  1.318711  103.765919
# 54945     20090682  cycling_path     Clementi  1.320501  103.767219
# 54946     20090682  cycling_path     Clementi  1.319475  103.766245
# 54947     20090682  cycling_path     Clementi  1.319475  103.766245
# 54948     20090682  cycling_path     Clementi  1.320330  103.767056
# 54949     20090682  cycling_path     Clementi  1.320330  103.767056
# ...
